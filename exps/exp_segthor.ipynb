# %%
# !nvidia-smi

# %% [markdown]
# ## Setup environment

# %%
# sync python module
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Setup config

# %%
import os

workspace_dir = '/nfs/Workspace/CardiacSegV2'
model_name = 'testnet'  #unet3d attention_unet DynUNet cotr unetr swinunetr unetcnx_a1 unest testnet
data_name = 'segthor'
sub_data_dir_name = 'segTHOR_train'
exp_name = 'exp_segthor_3_3_9_2' 
data_dict_file_name = 'exp_segthor_test.json' #exp_segthor_3_3_9_40_2.json

tune_mode = 'train'

# set exp dir
root_exp_dir = os.path.join(
    workspace_dir, 
    'exps',
    'exps',
    model_name,
    data_name,
    'tune_results'
)

# set data dir
root_data_dir = os.path.join(
    workspace_dir, 
    'dataset',
    data_name
)
data_dir = os.path.join(root_data_dir, sub_data_dir_name)

# data dict json path
data_dicts_json = os.path.join(workspace_dir, 'exps', 'data_dicts', data_name, data_dict_file_name)

# set model, log, eval dir
model_dir = os.path.join('./', 'models')
log_dir = os.path.join('./', 'logs')
eval_dir = os.path.join('./', 'evals')

# model path
best_checkpoint = os.path.join(model_dir, 'best_model.pth')
final_checkpoint = os.path.join(model_dir, 'final_model.pth')

# mkdir root exp dir
os.makedirs(root_exp_dir, exist_ok=True)

# for pretrain
pretrain_exp_name = 'exp_50'
pretrain_data_name = 'image_cas'
pretrain_model_dir = os.path.join(
    workspace_dir,
    'exps',
    'exps',
    model_name,
    pretrain_data_name,
    'pretrain',
    pretrain_exp_name,
    'models'
)
pretrain_checkpoint = os.path.join(pretrain_model_dir, 'model_bestValRMSE.pt')

# %cd {root_exp_dir}/..
# Out:
# /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor

# %% [markdown]
# ## Train TestNet

# %%
# training
# !PYTHONPATH={workspace_dir} /opt/conda/bin/python {workspace_dir}/expers/tune.py \
--tune_mode={tune_mode} \
--exp_name={exp_name} \
--data_name={data_name} \
--data_dir={data_dir} \
--root_exp_dir={root_exp_dir} \
--model_name={model_name}\
--model_dir={model_dir} \
--log_dir={log_dir} \
--eval_dir={eval_dir} \
--start_epoch=0 \
--val_every=20 \
--max_early_stop_count=20 \
--max_epoch=1  \
--data_dicts_json={data_dicts_json} \
--pin_memory \
--out_channels=2 \
--patch_size=2 \
--feature_size=48 \
--drop_rate=0.1 \
--depths 3 3 9 3 \
--kernel_size 7 \
--exp_rate 4 \
--norm_name='layer' \
--a_min=-80 \
--a_max=450 \
--space_x=1.0 \
--space_y=1.0 \
--space_z=1.0 \
--roi_x=128 \
--roi_y=128 \
--roi_z=128 \
--optim='AdamW' \
--lr=8e-4 \
--weight_decay=5e-4 \
--checkpoint={final_checkpoint} \
--use_init_weights \
--infer_post_process \
--deep_sup \
--resume_tuner \
--test_mode \
--save_eval_csv
# Out:
# Package pickle5 becomes unnecessary in Python 3.8 and above. Its presence may confuse libraries including Ray. Please uninstall the package.
# test mode
# resume tuner form /nfs/Workspace/CardiacSegV2/exps/exps/testnet/segthor/tune_results
# Passing in the experiment's `trainable` will be a required argument to `Tuner.restore` starting from version 2.5. Please specify the trainable to avoid this warning.
# run test mode ...
# cuda is available
# model: testnet
# patch size: 2
# ker size: 7
# exp rate: 4
# feature sizes: [48, 96, 192, 384]
# depths: [3, 3, 9, 3]
# drop rate: 0.1
# use init weights: True
# is conv stem: False
# use init weights
# skip encoder: None
# use deep sup
# loss: dice ce loss
# optimzer: AdamW
# {'lr': 0.0008, 'weight_decay': 0.0005}
# => loaded checkpoint '/nfs/Workspace/CardiacSegV2/exps/exps/testnet/segthor/tune_results/exp_segthor_3_3_9_2/main_b18d3_00000_0_exp=exp_exp_segthor_3_3_9_2_2024-06-11_11-13-56/models/best_model.pth' (epoch 2) (bestacc 0.48586779832839966) (early stop count 0)
# load json from /nfs/Workspace/CardiacSegV2/exps/data_dicts/segthor/exp_segthor_test.json
# train files (1): ['Patient_01_image']
# val files (1): ['Patient_10_image']
# test files (1): ['Patient_13_image']
# infer data: {'image': '/nfs/Workspace/CardiacSegV2/dataset/segthor/segTHOR_train/Patient_13/Patient_13_image.nii.gz', 'label': '/nfs/Workspace/CardiacSegV2/dataset/segthor/segTHOR_train/Patient_13/Patient_13_label.nii.gz'}
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# infer time: 41.937551498413086 sec
# use post process infer
# <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
# infer test time aug:
# dice: 0.06744821
# hd95: 270.53094
# infer test original:
# dice: 0.08563655
# hd95: 170.52272
# sensitivity: 0.40369365
# specificity: 0.9357866
#
# eval result:
# avg tt dice: 0.06744821
# avg tt hd95: 270.53094
# avg inf dice: 0.08563655
# avg inf hd95: 170.52272
# avg inf sensitivity: 0.40369365
# avg inf specificity: 0.9357866
# avg inf time: 41.937551498413086
#           patientId  tt_diceC    tt_hd95C  inf_diceC  inf_hd95C  inf_sensitivityC  inf_specificityC   inf_time
# 0  Patient_13_image  0.067448  270.530945   0.085637  170.52272          0.403694          0.935787  41.937551
# Session not detected. You should not be calling `report` outside `tuner.fit()` or while using the class API.
#   File "/nfs/Workspace/CardiacSegV2/expers/tune.py", line 489, in <module>
#     main_worker(args)
#   File "/nfs/Workspace/CardiacSegV2/expers/tune.py", line 359, in main_worker
#     tune.report(

# %% [markdown]
# ## Train UNETCNX

# %%
# training
# !PYTHONPATH={workspace_dir} /opt/conda/bin/python {workspace_dir}/expers/tune.py \
--tune_mode={tune_mode} \
--exp_name={exp_name} \
--data_name={data_name} \
--data_dir={data_dir} \
--root_exp_dir={root_exp_dir} \
--model_name={model_name}\
--model_dir={model_dir} \
--log_dir={log_dir} \
--eval_dir={eval_dir} \
--start_epoch=0 \
--val_every=20 \
--max_early_stop_count=20 \
--max_epoch=1  \
--data_dicts_json={data_dicts_json} \
--pin_memory \
--out_channels=2 \
--patch_size=4 \
--feature_size=48 \
--drop_rate=0.1 \
--depths 3 3 9 3 \
--kernel_size 7 \
--exp_rate 4 \
--norm_name='layer' \
--a_min=-80 \
--a_max=450 \
--space_x=1.0 \
--space_y=1.0 \
--space_z=1.0 \
--roi_x=128 \
--roi_y=128 \
--roi_z=128 \
--optim='AdamW' \
--lr=7e-4 \
--weight_decay=5e-4 \
--checkpoint={final_checkpoint} \
--use_init_weights \
--infer_post_process \
--deep_sup \
#--resume_tuner \
#--test_mode \
#--save_eval_csv
# Out:
# Package pickle5 becomes unnecessary in Python 3.8 and above. Its presence may confuse libraries including Ray. Please uninstall the package.
# 2024-06-11 15:31:42,113	INFO worker.py:1625 -- Started a local Ray instance.
# 2024-06-11 15:31:43,170	INFO tune.py:218 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# The `local_dir` argument of `Experiment is deprecated. Use `storage_path` or set the `TUNE_RESULT_DIR` environment variable instead.
# 2024-06-11 15:31:43,184	INFO tensorboardx.py:172 -- pip install "ray[tune]" to see TensorBoard files.
# 2024-06-11 15:31:43,184	WARNING callback.py:142 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2024-06-11 15:31:43 (running for 00:00:00.25)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# (func pid=1024652) a_max 450.0
# (func pid=1024652) a_min -80.0
# (func pid=1024652) space_x 1.0
# (func pid=1024652) roi_x 128
# (func pid=1024652) lr 0.0007
# (func pid=1024652) weight_decay 0.0005
# (func pid=1024652) warmup_epochs 50
# (func pid=1024652) max_epochs 1
# (func pid=1024652) cuda is available
# (func pid=1024652) model: unetcnx_a1
# (func pid=1024652) patch size: 4
# (func pid=1024652) ker size: 7
# (func pid=1024652) exp rate: 4
# (func pid=1024652) feature sizes: [48, 96, 192, 384]
# (func pid=1024652) depths: [3, 3, 9, 3]
# (func pid=1024652) drop rate: 0.1
# (func pid=1024652) use init weights: True
# (func pid=1024652) is conv stem: False
# (func pid=1024652) use init weights
# (func pid=1024652) skip encoder: None
# (func pid=1024652) use deep sup
# (func pid=1024652) loss: dice ce loss
# (func pid=1024652) optimzer: AdamW
# (func pid=1024652) {'lr': 0.0007, 'weight_decay': 0.0005}
# (func pid=1024652) load json from /nfs/Workspace/CardiacSegV2/exps/data_dicts/segthor/exp_segthor_test.json
# (func pid=1024652) train files (1): ['Patient_01_image']
# (func pid=1024652) val files (1): ['Patient_10_image']
# (func pid=1024652) test files (1): ['Patient_13_image']
# (func pid=1024652)
# (func pid=1024652) load train dataset ...
# (func pid=1024652) Using MONAI Cache Dataset
# (func pid=1024652) monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# (func pid=1024652) <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# (func pid=1024652) monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# Loading dataset:   0%|          | 0/1 [00:00<?, ?it/s]
# == Status ==
# Current time: 2024-06-11 15:31:54 (running for 00:00:10.82)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:31:59 (running for 00:00:15.82)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:32:04 (running for 00:00:20.83)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:32:09 (running for 00:00:25.83)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:32:14 (running for 00:00:30.84)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:32:19 (running for 00:00:35.84)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# (func pid=1024652)
# (func pid=1024652) load val dataset ...
# (func pid=1024652) Using MONAI Cache Dataset
# Loading dataset: 100%|██████████| 1/1 [00:27<00:00, 27.20s/it]
# Loading dataset:   0%|          | 0/1 [00:00<?, ?it/s]
# == Status ==
# Current time: 2024-06-11 15:32:24 (running for 00:00:40.85)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:32:29 (running for 00:00:45.85)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:32:34 (running for 00:00:50.86)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:32:39 (running for 00:00:55.86)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# Loading dataset: 100%|██████████| 1/1 [00:19<00:00, 19.53s/it]
# Training (X / X Steps) (loss=X.X):   0%|          | 0/1 [00:00<?, ?it/s]
# == Status ==
# Current time: 2024-06-11 15:32:44 (running for 00:01:00.87)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# [Epoch 0] Training (0 Steps) (loss=1.31256): 100%|██████████| 1/1 [00:07<00:00,  7.80s/it]
# [Epoch 0] Training (0 Steps) (loss=1.31256): 100%|██████████| 1/1 [00:07<00:00,  7.91s/it]
# Training (X / X Steps) (loss=X.X):   0%|          | 0/1 [00:00<?, ?it/s]
# == Status ==
# Current time: 2024-06-11 15:32:49 (running for 00:01:05.87)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# [Epoch 1] Training (1 Steps) (loss=1.00765): 100%|██████████| 1/1 [00:05<00:00,  5.49s/it]
# [Epoch 1] Training (1 Steps) (loss=1.00765): 100%|██████████| 1/1 [00:05<00:00,  5.60s/it]
# Validate (X / X Steps) (dice=X.X):   0%|          | 0/1 [00:00<?, ?it/s]
# == Status ==
# Current time: 2024-06-11 15:32:54 (running for 00:01:10.88)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:32:59 (running for 00:01:15.88)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:33:04 (running for 00:01:20.89)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:33:09 (running for 00:01:25.89)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:33:14 (running for 00:01:30.90)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:33:19 (running for 00:01:35.90)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:33:24 (running for 00:01:40.91)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:33:29 (running for 00:01:45.91)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# == Status ==
# Current time: 2024-06-11 15:33:34 (running for 00:01:50.92)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+
# | Trial name       | status   | loc                   | exp                  |
# |------------------+----------+-----------------------+----------------------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |
# +------------------+----------+-----------------------+----------------------+
#
#
# Validate (2 / 10 Steps): 100%|██████████| 1/1 [00:44<00:00, 44.20s/it]
# Validate (2 / 10 Steps): 100%|██████████| 1/1 [00:44<00:00, 44.31s/it]
# (func pid=1024652) Saving checkpoint ./models/best_model.pth
# (func pid=1024652) Best Model Was Saved ! Current Best Avg. Dice: 0.5287750959396362 Current Avg. Dice: 0.5287750959396362
# Result for main_b49cd_00000:
#   date: 2024-06-11_15-33-38
#   done: false
#   esc: 0
#   hostname: cardiac00-5747bf8bc-7xpf7
#   iterations_since_restore: 1
#   node_ip: 10.32.124.135
#   pid: 1024652
#   time_since_restore: 109.00593256950378
#   time_this_iter_s: 109.00593256950378
#   time_total_s: 109.00593256950378
#   timestamp: 1718120018
#   training_iteration: 1
#   trial_id: b49cd_00000
#   tt_dice: 0
#   tt_hd95: 0
#   val_bst_acc: 0.5287750959396362
#
# (func pid=1024652) Saving checkpoint ./models/final_model.pth
# (func pid=1024652) Final Model Was Saved ! Current Best Avg. Dice: 0.5287750959396362 Current Avg. Dice: 0.5287750959396362
# (func pid=1024652) cuda is available
# (func pid=1024652) model: unetcnx_a1
# (func pid=1024652) patch size: 4
# (func pid=1024652) ker size: 7
# (func pid=1024652) exp rate: 4
# (func pid=1024652) feature sizes: [48, 96, 192, 384]
# (func pid=1024652) depths: [3, 3, 9, 3]
# (func pid=1024652) drop rate: 0.1
# (func pid=1024652) use init weights: True
# (func pid=1024652) is conv stem: False
# (func pid=1024652) use init weights
# (func pid=1024652) skip encoder: None
# (func pid=1024652) use deep sup
# (func pid=1024652) loss: dice ce loss
# (func pid=1024652) optimzer: AdamW
# (func pid=1024652) {'lr': 0.0007, 'weight_decay': 0.0005}
# (func pid=1024652) => loaded checkpoint './models/best_model.pth' (epoch 2) (bestacc 0.5287750959396362) (early stop count 0)
# (func pid=1024652) load json from /nfs/Workspace/CardiacSegV2/exps/data_dicts/segthor/exp_segthor_test.json
# (func pid=1024652) train files (1): ['Patient_01_image']
# (func pid=1024652) val files (1): ['Patient_10_image']
# (func pid=1024652) test files (1): ['Patient_13_image']
# (func pid=1024652) infer data: {'image': '/nfs/Workspace/CardiacSegV2/dataset/segthor/segTHOR_train/Patient_13/Patient_13_image.nii.gz', 'label': '/nfs/Workspace/CardiacSegV2/dataset/segthor/segTHOR_train/Patient_13/Patient_13_label.nii.gz'}
# == Status ==
# Current time: 2024-06-11 15:33:43 (running for 00:01:59.82)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                   | exp                  |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |         0 |         0 |      0.528775 |     0 |
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2024-06-11 15:33:48 (running for 00:02:04.83)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                   | exp                  |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |         0 |         0 |      0.528775 |     0 |
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2024-06-11 15:33:53 (running for 00:02:09.83)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                   | exp                  |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |         0 |         0 |      0.528775 |     0 |
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2024-06-11 15:33:58 (running for 00:02:14.84)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                   | exp                  |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |         0 |         0 |      0.528775 |     0 |
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2024-06-11 15:34:03 (running for 00:02:19.85)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                   | exp                  |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |         0 |         0 |      0.528775 |     0 |
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2024-06-11 15:34:08 (running for 00:02:24.85)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                   | exp                  |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |         0 |         0 |      0.528775 |     0 |
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2024-06-11 15:34:13 (running for 00:02:29.86)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                   | exp                  |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |         0 |         0 |      0.528775 |     0 |
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2024-06-11 15:34:18 (running for 00:02:34.86)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                   | exp                  |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |         0 |         0 |      0.528775 |     0 |
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2024-06-11 15:34:23 (running for 00:02:39.87)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:V100)
# Result logdir: /nfs/Workspace/CardiacSegV2/exps/exps/unetcnx_a1/segthor/tune_results/exp_segthor_3_3_9_2
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                   | exp                  |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------|
# | main_b49cd_00000 | RUNNING  | 10.32.124.135:1024652 | {'exp': 'exp_se_12c0 |         0 |         0 |      0.528775 |     0 |
# +------------------+----------+-----------------------+----------------------+-----------+-----------+---------------+-------+
#
#
# ^C

# %% [markdown]
# ## Train other models

# %%
# training
# !PYTHONPATH={workspace_dir} /opt/conda/bin/python {workspace_dir}/expers/tune.py \
--tune_mode={tune_mode} \
--exp_name={exp_name} \
--data_name={data_name} \
--data_dir={data_dir} \
--root_exp_dir={root_exp_dir} \
--model_name={model_name}\
--model_dir={model_dir} \
--log_dir={log_dir} \
--eval_dir={eval_dir} \
--start_epoch=0 \
--val_every=20 \
--max_early_stop_count=20 \
--max_epoch=2  \
--data_dicts_json={data_dicts_json} \
--pin_memory \
--out_channels=2 \
--patch_size=4 \
--feature_size=48 \
--drop_rate=0.1 \
--depths 3 3 9 3 \
--kernel_size 7 \
--exp_rate 4 \
--norm_name='layer' \
--a_min=-80 \
--a_max=450 \
--space_x=1.0 \
--space_y=1.0 \
--space_z=1.0 \
--roi_x=128 \
--roi_y=128 \
--roi_z=128 \
--optim='AdamW' \
--lr=5e-4 \
--weight_decay=5e-4 \
--checkpoint={final_checkpoint} \
--use_init_weights \
--infer_post_process \
#--resume_tuner \
#--save_eval_csv \
#--test_mode

# %% [markdown]
# ## Analysis

# %%
# !PYTHONPATH=/nfs/Workspace/CardiacSeg /opt/conda/bin/python /nfs/Workspace/CardiacSeg/expers/tune_anal.py \
--exp_name={exp_name} \
--local_dir={root_exp_dir}
