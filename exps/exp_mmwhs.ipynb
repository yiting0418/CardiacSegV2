# %%
# !nvidia-smi
# Out:
# Mon Jul  3 11:28:16 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.48.07    Driver Version: 515.48.07    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:06:00.0 Off |                  N/A |
# | 23%   32C    P8     9W / 250W |      0MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Setup environment

# %%
# sync python module
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Setup config

# %%
import os

workspace_dir = '/nfs/Workspace/CardiacSeg'
model_name = 'unet3d'
data_name = 'mmwhs'
exp_name = 'exp_2_tn2'
data_dict_file_name = 'exp_2.json'

tune_mode = 'train'

root_exp_dir = os.path.join(
    workspace_dir, 
    'exps',
    'exps',
    model_name,
    data_name,
    'tune_results'
)

root_data_dir = os.path.join(
    workspace_dir, 
    'dataset',
    data_name
)

data_dir = os.path.join(root_data_dir)
data_dicts_json = os.path.join(workspace_dir, 'exps', 'data_dicts', data_name, data_dict_file_name)

model_dir = os.path.join('./', 'models')
log_dir = os.path.join('./', 'logs')
eval_dir = os.path.join('./', 'evals')

best_checkpoint = os.path.join(model_dir, 'best_model.pth')
final_checkpoint = os.path.join(model_dir, 'final_model.pth')

pretrain_exp_name = 'exp_50'
pretrain_data_name = 'image_cas'
pretrain_model_dir = os.path.join(
    workspace_dir,
    'exps',
    'exps',
    model_name,
    pretrain_data_name,
    'pretrain',
    pretrain_exp_name,
    'models'
)
pretrain_checkpoint = os.path.join(pretrain_model_dir, 'model_bestValRMSE.pt')

os.makedirs(root_exp_dir, exist_ok=True)

# %cd {root_exp_dir}/../
# Out:
# /nfs/Workspace/CardiacSeg/exps/exps/unetcnx_a1/mmwhs

# %% [markdown]
# ## Train UNETCNX

# %%
# training
# !PYTHONPATH=/nfs/Workspace/CardiacSeg /opt/conda/bin/python /nfs/Workspace/CardiacSeg/expers/tune.py \
--tune_mode={tune_mode} \
--exp_name={exp_name} \
--data_name={data_name} \
--data_dir={data_dir} \
--root_exp_dir={root_exp_dir} \
--model_name={model_name}\
--model_dir={model_dir} \
--log_dir={log_dir} \
--eval_dir={eval_dir} \
--start_epoch=0 \
--val_every=20 \
--max_early_stop_count=20 \
--max_epoch=8000  \
--data_dicts_json={data_dicts_json} \
--pin_memory \
--out_channels=8 \
--patch_size=4 \
--feature_size=48 \
--drop_rate=0.1 \
--depths 3 3 9 3 \
--kernel_size 7 \
--exp_rate 4 \
--norm_name='layer' \
--a_min=-70 \
--a_max=677 \
--space_x=1.0 \
--space_y=1.0 \
--space_z=1.0 \
--roi_x=96 \
--roi_y=96 \
--roi_z=96 \
--optim='AdamW' \
--lr=7e-4 \
--weight_decay=5e-4 \
--checkpoint={final_checkpoint} \
--use_init_weights \
--deep_sup \
--infer_post_process \
# --resume_tuner \
# --test_mode \
# --save_eval_csv \
# Out:
# test mode
# resume tuner form /nfs/Workspace/CardiacSeg/exps/exps/unetcnx_a1/mmwhs/tune_results
# Passing in the experiment's `trainable` will be a required argument to `Tuner.restore` starting from version 2.5. Please specify the trainable to avoid this warning.
# run test mode ...
# cuda is available
# model: unetcnx_a1
# patch size: 4
# ker size: 7
# exp rate: 4
# feature sizes: [48, 96, 192, 384]
# depths: [3, 3, 9, 3]
# drop rate: 0.1
# use init weights: True
# is conv stem: False
# use init weights
# use deep sup
# loss: dice ce loss
# optimzer: AdamW
# {'lr': 0.0007, 'weight_decay': 0.0005}
# => loaded checkpoint '/nfs/Workspace/CardiacSeg/exps/exps/unetcnx_a1/mmwhs/tune_results/exp_2_tn2/main_ba545_00000_0_exp=exp_exp_2_tn2_2023-06-02_13-38-16/models/best_model.pth' (epoch 881) (bestacc 0.9047536253929138) (early stop count 0)
# load json from /nfs/Workspace/CardiacSeg/exps/data_dicts/mmwhs/exp_2.json
# train files (8): ['ct_train_1001_image', 'ct_train_1002_image', 'ct_train_1003_image', 'ct_train_1004_image', 'ct_train_1005_image', 'ct_train_1006_image', 'ct_train_1007_image', 'ct_train_1008_image']
# val files (2): ['ct_train_1009_image', 'ct_train_1010_image']
# test files (10): ['ct_train_1011_image', 'ct_train_1012_image', 'ct_train_1013_image', 'ct_train_1014_image', 'ct_train_1015_image', 'ct_train_1016_image', 'ct_train_1017_image', 'ct_train_1018_image', 'ct_train_1019_image', 'ct_train_1020_image']
# infer data: {'image': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1011_image.nii.gz', 'label': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1011_label.nii.gz'}
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# infer time: 3.8123161792755127 sec
# use post process infer
# <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
# infer test time aug:
# dice: [0.9492563 0.8846356 0.9272986 0.8808433 0.8588508 0.9538112 0.8426827]
# hd95: [2.828427  7.635385  5.0990195 6.164414  3.4641016 1.7320508 7.8740077]
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# infer test original:
# dice: [0.94790757 0.89236397 0.9274366  0.8777505  0.85246056 0.94404
#  0.8380474 ]
# hd95: [ 5.7445626 14.456832  11.357817  14.6969385  7.3484693  4.1231055
#  15.556349 ]
# infer data: {'image': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1012_image.nii.gz', 'label': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1012_label.nii.gz'}
# <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# infer time: 4.530785799026489 sec
# use post process infer
# <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
# infer test time aug:
# dice: [0.9443912  0.8724982  0.9046222  0.82025546 0.86937094 0.95132416
#  0.9354503 ]
# hd95: [ 2.4494898 12.083046   8.306623  31.827662   3.         3.
#   2.236068 ]
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# infer test original:
# dice: [0.9401973  0.86829543 0.8983568  0.8082409  0.86325556 0.9353866
#  0.9245914 ]
# hd95: [ 4.8989797 23.727621  14.96663   62.94442    5.3851647  6.3324122
#   4.       ]
# infer data: {'image': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1013_image.nii.gz', 'label': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1013_label.nii.gz'}
# <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# infer time: 2.259687900543213 sec
# use post process infer
# <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
# infer test time aug:
# dice: [0.8972034  0.81900835 0.882323   0.8393259  0.89538175 0.9701894
#  0.761347  ]
# hd95: [ 3.7416575 13.928389  11.74734    9.486833   3.7416575  1.4142135
#  58.40548  ]
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# infer test original:
# dice: [0.8901676  0.8015827  0.873956   0.82357025 0.88287497 0.95505565
#  0.7595374 ]
# hd95: [  8.062258   31.08054    25.079872   22.36068     8.185352    3.3166249
#  110.864784 ]
# infer data: {'image': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1014_image.nii.gz', 'label': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1014_label.nii.gz'}
# <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# infer time: 0.15948700904846191 sec
# use post process infer
# <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
# infer test time aug:
# dice: [0.92219514 0.81911635 0.8900667  0.8289558  0.8123816  0.961161
#  0.81577283]
# hd95: [ 4.         8.306623   8.485281  10.049875   5.0990195  3.
#  15.6205   ]
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# infer test original:
# dice: [0.9142196  0.8040349  0.8858256  0.8199995  0.7922225  0.95323664
#  0.8070472 ]
# hd95: [12.369317 23.452078 25.199205 28.530685 16.643316  9.486833 41.880783]
# infer data: {'image': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1015_image.nii.gz', 'label': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1015_label.nii.gz'}
# <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# infer time: 7.4142820835113525 sec
# use post process infer
# <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
# infer test time aug:
# dice: [0.9228513  0.8703945  0.9449129  0.9205053  0.90557283 0.96508634
#  0.6645884 ]
# hd95: [ 3.         5.3851647  2.828427   3.6055512  2.4494898  2.
#  37.385826 ]
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# infer test original:
# dice: [0.91792077 0.8674897  0.9317521  0.91731167 0.9025522  0.96077025
#  0.66169685]
# hd95: [ 5.3851647  9.110434   5.3851647  6.0827627  4.1231055  3.1622777
#  61.878914 ]
# infer data: {'image': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1016_image.nii.gz', 'label': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1016_label.nii.gz'}
# <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# infer time: 0.12044095993041992 sec
# use post process infer
# <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
# infer test time aug:
# dice: [0.9765542  0.9174641  0.96000326 0.9367212  0.91466576 0.9818861
#  0.8921201 ]
# hd95: [1.4142135 3.1622777 2.4494898 3.        2.236068  1.        7.071068 ]
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# infer test original:
# dice: [0.9644799  0.90346783 0.9537267  0.9260662  0.88322115 0.9678294
#  0.8845238 ]
# hd95: [ 4.1231055  9.110434   7.1414285  8.246211   6.928203   2.828427
#  18.973665 ]
# infer data: {'image': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1017_image.nii.gz', 'label': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1017_label.nii.gz'}
# <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# infer time: 7.270016431808472 sec
# use post process infer
# <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
# infer test time aug:
# dice: [0.94288516 0.867691   0.76054466 0.8769744  0.9115465  0.9739425
#  0.80275285]
# hd95: [ 2.236068   9.486833  14.773279  21.213203   3.1622777  1.
#  25.114723 ]
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# infer test original:
# dice: [0.9363194  0.87033296 0.75386167 0.8767097  0.8955627  0.9626283
#  0.7983971 ]
# hd95: [ 4.1231055 15.6205    24.758837  35.36948    6.         2.236068
#  42.201897 ]
# infer data: {'image': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1018_image.nii.gz', 'label': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1018_label.nii.gz'}
# <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# infer time: 2.329069137573242 sec
# use post process infer
# <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
# infer test time aug:
# dice: [0.9615336  0.8568517  0.8716084  0.9275387  0.81944567 0.9764906
#  0.78065366]
# hd95: [ 3.7416575 10.29563    6.3874106  3.1622777  3.3166249  1.4142135
#   9.433981 ]
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# infer test original:
# dice: [0.9540579  0.84956074 0.86566466 0.9112192  0.79887426 0.9618203
#  0.76840615]
# hd95: [ 8.124039  21.        13.416408   7.28011    7.3484693  3.1622777
#  19.039429 ]
# infer data: {'image': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1019_image.nii.gz', 'label': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1019_label.nii.gz'}
# <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# infer time: 7.3873960971832275 sec
# use post process infer
# <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
# infer test time aug:
# dice: [0.8792168  0.84982765 0.91988766 0.86959726 0.9073492  0.3571532
#  0.57814044]
# hd95: [ 4.1231055  5.0990195  9.69536   11.74734    4.690416  38.28838
#  28.199278 ]
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# infer test original:
# dice: [0.87535286 0.84091026 0.9180676  0.86543953 0.90146416 0.35415018
#  0.5737996 ]
# hd95: [ 7.6811457 10.        18.138357  21.023796   9.110434  66.40143
#  53.347916 ]
# infer data: {'image': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1020_image.nii.gz', 'label': '/nfs/Workspace/CardiacSeg/dataset/mmwhs/ct_train/ct_train_1020_label.nii.gz'}
# <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# infer time: 2.243223190307617 sec
# use post process infer
# <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
# infer test time aug:
# dice: [0.95630014 0.91892177 0.9744831  0.9224856  0.9230938  0.9738088
#  0.93561107]
# hd95: [2.        4.        2.        3.7416575 1.7320508 1.        5.3851647]
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# infer test original:
# dice: [0.95307887 0.90974075 0.9682186  0.91163313 0.91410524 0.96771777
#  0.928777  ]
# hd95: [ 5.196152  10.049875   5.        10.29563    4.690416   3.1622777
#  16.27882  ]
#
# eval result:
# avg tt dice: 0.8825625
# avg tt hd95: 8.116495
# avg inf dice: 0.8744334
# avg inf hd95: 16.636967
# avg inf time: 3.752670478820801
#              patientId  tt_diceLV  tt_diceRV  tt_diceLA  tt_diceRA  tt_diceMLV  tt_diceAA  tt_dicePA  tt_hd95LV  tt_hd95RV  tt_hd95LA  tt_hd95RA  tt_hd95MLV  tt_hd95AA  tt_hd95PA  inf_diceLV  inf_diceRV  inf_diceLA  inf_diceRA  inf_diceMLV  inf_diceAA  inf_dicePA  inf_hd95LV  inf_hd95RV  inf_hd95LA  inf_hd95RA  inf_hd95MLV  inf_hd95AA  inf_hd95PA  inf_time
# 9  ct_train_1020_image   0.956300   0.918922   0.974483   0.922486    0.923094   0.973809   0.935611   2.000000   4.000000   2.000000   3.741657    1.732051   1.000000   5.385165    0.953079    0.909741    0.968219    0.911633     0.914105    0.967718    0.928777    5.196152   10.049875    5.000000   10.295630     4.690416    3.162278   16.278820  2.243223
# Session not detected. You should not be calling `report` outside `tuner.fit()` or while using the class API.
#   File "/nfs/Workspace/CardiacSeg/expers/tune.py", line 460, in <module>
#     main_worker(args)
#   File "/nfs/Workspace/CardiacSeg/expers/tune.py", line 330, in main_worker
#     tune.report(

# %% [markdown]
# ## Train other model

# %%
# training
# !PYTHONPATH=/nfs/Workspace/CardiacSeg /opt/conda/bin/python /nfs/Workspace/CardiacSeg/expers/tune.py \
--tune_mode={tune_mode} \
--exp_name={exp_name} \
--data_name={data_name} \
--data_dir={data_dir} \
--root_exp_dir={root_exp_dir} \
--model_name={model_name}\
--model_dir={model_dir} \
--log_dir={log_dir} \
--eval_dir={eval_dir} \
--start_epoch=0 \
--val_every=20 \
--max_early_stop_count=20 \
--max_epoch=8000  \
--data_dicts_json={data_dicts_json} \
--pin_memory \
--out_channels=8 \
--patch_size=4 \
--feature_size=48 \
--drop_rate=0.1 \
--depths 3 3 9 3 \
--kernel_size 7 \
--exp_rate 4 \
--norm_name='layer' \
--a_min=-70 \
--a_max=677 \
--space_x=1.0 \
--space_y=1.0 \
--space_z=1.0 \
--roi_x=96 \
--roi_y=96 \
--roi_z=96 \
--optim='AdamW' \
--lr=7e-4 \
--weight_decay=5e-4 \
--checkpoint={final_checkpoint} \
--use_init_weights \
--infer_post_process \
# --resume_tuner \
# --test_mode \
# --save_eval_csv \

# %% [markdown]
# ## Analysis

# %%
# !PYTHONPATH=/nfs/Workspace/CardiacSeg /opt/conda/bin/python /nfs/Workspace/CardiacSeg/expers/tune_anal.py \
--exp_name={exp_name} \
--local_dir={root_exp_dir}
# Out:
# Loading results from /nfs/Workspace/CardiacSeg/exps/exps/unetcnx_a0/mmwhs/tune_results/tmp...
# /opt/conda/lib/python3.9/site-packages/ray/tune/tuner.py:255: UserWarning: Passing in the experiment's `trainable` will be a required argument to `Tuner.restore` starting from version 2.5. Please specify the trainable to avoid this warning.
#   warnings.warn(warning_message)
# 2023-05-05 05:57:27,424 - No `self.trials`. Drawing logdirs from checkpoint file. This may result in some information that is out of sync, as checkpointing is periodic.
# Trial 7ffb2_00000:  {'exp': {'exp': 'tmp'}} 0.85568607 0.22231789
#
# Best trial 7ffb2_00000:
# config: {'exp': {'exp': 'tmp'}}
# tt_dice: 0.85568607
# tt_hd95: 21.87371429569567
# inf_dice: 0.22231789
# inf_hd95: 114.227495408918
# best log dir: /nfs/Workspace/CardiacSeg/exps/exps/unetcnx_a0/mmwhs/tune_results/tmp/main_7ffb2_00000_0_exp=exp_tmp_2023-04-23_03-32-40
# final early stop count: 20
# final epoch: 1920
# best val dice: 0.9036121964454651
